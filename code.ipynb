# %%
# Import necessary libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support, r2_score

import warnings
import os

# %%
# Load the dataset
i = pd.read_excel("./dataset/Internal.xlsx")
e = pd.read_excel("./dataset/External.xlsx")

# %%
df1 = i.copy()
df2 = e.copy()

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (51336, 26)
# (51336, 62)

# %%
# Remove nulls
df1 = df1.loc[df1['Age_Oldest_TL'] != -99999]

# %%
# Remove Columns with more than 10000 missing values
columns_to_be_removed = []

for i in df2.columns:
    if df2.loc[df2[i] == -99999].shape[0] > 10000:
        columns_to_be_removed .append(i)



df2 = df2.drop(columns_to_be_removed, axis =1)

# %%
# Remove Rows with missing values
for i in df2.columns:
    df2 = df2.loc[ df2[i] != -99999 ]

# %%
# NA values in df2
df2.isna().sum()
# Out:
# PROSPECTID                    0
# time_since_recent_payment     0
# num_times_delinquent          0
# max_recent_level_of_deliq     0
# num_deliq_6mts                0
# num_deliq_12mts               0
# num_deliq_6_12mts             0
# num_times_30p_dpd             0
# num_times_60p_dpd             0
# num_std                       0
# num_std_6mts                  0
# num_std_12mts                 0
# num_sub                       0
# num_sub_6mts                  0
# num_sub_12mts                 0
# num_dbt                       0
# num_dbt_6mts                  0
# num_dbt_12mts                 0
# num_lss                       0
# num_lss_6mts                  0
# num_lss_12mts                 0
# recent_level_of_deliq         0
# tot_enq                       0
# CC_enq                        0
# CC_enq_L6m                    0
# CC_enq_L12m                   0
# PL_enq                        0
# PL_enq_L6m                    0
# PL_enq_L12m                   0
# time_since_recent_enq         0
# enq_L12m                      0
# enq_L6m                       0
# enq_L3m                       0
# MARITALSTATUS                 0
# EDUCATION                     0
# AGE                           0
# GENDER                        0
# NETMONTHLYINCOME              0
# Time_With_Curr_Empr           0
# pct_of_active_TLs_ever        0
# pct_opened_TLs_L6m_of_L12m    0
# pct_currentBal_all_TL         0
# CC_Flag                       0
# PL_Flag                       0
# pct_PL_enq_L6m_of_L12m        0
# pct_CC_enq_L6m_of_L12m        0
# pct_PL_enq_L6m_of_ever        0
# pct_CC_enq_L6m_of_ever        0
# HL_Flag                       0
# GL_Flag                       0
# last_prod_enq2                0
# first_prod_enq2               0
# Credit_Score                  0
# Approved_Flag                 0
# dtype: int64

# %%
# Checking common column names
for i in list(df1.columns):
    if i in list(df2.columns):
        print (i)
# Out:
# PROSPECTID

# %%
# Merge the two dataframes, inner join so that no nulls are present
df = pd.merge( df1, df2, how ='inner', left_on = ['PROSPECTID'], right_on = ['PROSPECTID'] )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42064 entries, 0 to 42063
# Data columns (total 79 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROSPECTID                  42064 non-null  int64
#  1   Total_TL                    42064 non-null  int64
#  2   Tot_Closed_TL               42064 non-null  int64
#  3   Tot_Active_TL               42064 non-null  int64
#  4   Total_TL_opened_L6M         42064 non-null  int64
#  5   Tot_TL_closed_L6M           42064 non-null  int64
#  6   pct_tl_open_L6M             42064 non-null  float64
#  7   pct_tl_closed_L6M           42064 non-null  float64
#  8   pct_active_tl               42064 non-null  float64
#  9   pct_closed_tl               42064 non-null  float64
#  10  Total_TL_opened_L12M        42064 non-null  int64
#  11  Tot_TL_closed_L12M          42064 non-null  int64
#  12  pct_tl_open_L12M            42064 non-null  float64
#  13  pct_tl_closed_L12M          42064 non-null  float64
#  14  Tot_Missed_Pmnt             42064 non-null  int64
#  15  Auto_TL                     42064 non-null  int64
#  16  CC_TL                       42064 non-null  int64
#  17  Consumer_TL                 42064 non-null  int64
#  18  Gold_TL                     42064 non-null  int64
#  19  Home_TL                     42064 non-null  int64
#  20  PL_TL                       42064 non-null  int64
#  21  Secured_TL                  42064 non-null  int64
#  22  Unsecured_TL                42064 non-null  int64
#  23  Other_TL                    42064 non-null  int64
#  24  Age_Oldest_TL               42064 non-null  int64
#  25  Age_Newest_TL               42064 non-null  int64
#  26  time_since_recent_payment   42064 non-null  int64
#  27  num_times_delinquent        42064 non-null  int64
#  28  max_recent_level_of_deliq   42064 non-null  int64
#  29  num_deliq_6mts              42064 non-null  int64
#  30  num_deliq_12mts             42064 non-null  int64
#  31  num_deliq_6_12mts           42064 non-null  int64
#  32  num_times_30p_dpd           42064 non-null  int64
#  33  num_times_60p_dpd           42064 non-null  int64
#  34  num_std                     42064 non-null  int64
#  35  num_std_6mts                42064 non-null  int64
#  36  num_std_12mts               42064 non-null  int64
#  37  num_sub                     42064 non-null  int64
#  38  num_sub_6mts                42064 non-null  int64
#  39  num_sub_12mts               42064 non-null  int64
#  40  num_dbt                     42064 non-null  int64
#  41  num_dbt_6mts                42064 non-null  int64
#  42  num_dbt_12mts               42064 non-null  int64
#  43  num_lss                     42064 non-null  int64
#  44  num_lss_6mts                42064 non-null  int64
#  45  num_lss_12mts               42064 non-null  int64
#  46  recent_level_of_deliq       42064 non-null  int64
#  47  tot_enq                     42064 non-null  int64
#  48  CC_enq                      42064 non-null  int64
#  49  CC_enq_L6m                  42064 non-null  int64
#  50  CC_enq_L12m                 42064 non-null  int64
#  51  PL_enq                      42064 non-null  int64
#  52  PL_enq_L6m                  42064 non-null  int64
#  53  PL_enq_L12m                 42064 non-null  int64
#  54  time_since_recent_enq       42064 non-null  int64
#  55  enq_L12m                    42064 non-null  int64
#  56  enq_L6m                     42064 non-null  int64
#  57  enq_L3m                     42064 non-null  int64
#  58  MARITALSTATUS               42064 non-null  object
#  59  EDUCATION                   42064 non-null  object
#  60  AGE                         42064 non-null  int64
#  61  GENDER                      42064 non-null  object
#  62  NETMONTHLYINCOME            42064 non-null  int64
#  63  Time_With_Curr_Empr         42064 non-null  int64
#  64  pct_of_active_TLs_ever      42064 non-null  float64
#  65  pct_opened_TLs_L6m_of_L12m  42064 non-null  float64
#  66  pct_currentBal_all_TL       42064 non-null  float64
#  67  CC_Flag                     42064 non-null  int64
#  68  PL_Flag                     42064 non-null  int64
#  69  pct_PL_enq_L6m_of_L12m      42064 non-null  float64
#  70  pct_CC_enq_L6m_of_L12m      42064 non-null  float64
#  71  pct_PL_enq_L6m_of_ever      42064 non-null  float64
#  72  pct_CC_enq_L6m_of_ever      42064 non-null  float64
#  73  HL_Flag                     42064 non-null  int64
#  74  GL_Flag                     42064 non-null  int64
#  75  last_prod_enq2              42064 non-null  object
#  76  first_prod_enq2             42064 non-null  object
#  77  Credit_Score                42064 non-null  int64
#  78  Approved_Flag               42064 non-null  object
# dtypes: float64(13), int64(60), object(6)
# memory usage: 25.4+ MB

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
# check how many columns are categorical
categorical_log = []
numerical_log = []

for i in df.columns:
    if i in ['PROSPECTID', 'Approved_Flag']:
        continue
    if df[i].dtype == 'object' :
        categorical_log.append(i)
        print(df[i].value_counts(), end = '\n\n')
    else:
        numerical_log.append(i)
# Out:
# MARITALSTATUS
# Married    30886
# Single     11178
# Name: count, dtype: int64
#
# EDUCATION
# GRADUATE          14140
# 12TH              11703
# SSC                7241
# UNDER GRADUATE     4572
# OTHERS             2291
# POST-GRADUATE      1898
# PROFESSIONAL        219
# Name: count, dtype: int64
#
# GENDER
# M    37345
# F     4719
# Name: count, dtype: int64
#
# last_prod_enq2
# ConsumerLoan    16480
# others          13653
# PL               7553
# CC               2195
# AL               1353
# HL                830
# Name: count, dtype: int64
#
# first_prod_enq2
# others          20640
# ConsumerLoan    11075
# PL               4431
# AL               2641
# CC               1988
# HL               1289
# Name: count, dtype: int64

# %%
# Drop the target variable from the categorical_log for chi-square test.
# categorical_log.remove('Approved_Flag')

# %%
# Chi-square test
for i in categorical_log:
    chi2, pval, _, _ = chi2_contingency(pd.crosstab(df[i], df['Approved_Flag']))
    print(f'{i} : {pval}')
    
# Since all the p-values are less than 0.05, So all the categorical variables are significant.
# Out:
# MARITALSTATUS : 3.578180861038862e-233
# EDUCATION : 2.6942265249737532e-30
# GENDER : 1.907936100186563e-05
# last_prod_enq2 : 0.0
# first_prod_enq2 : 7.84997610555419e-287

# %%
numerical_log
# Out:
# ['Total_TL',
#  'Tot_Closed_TL',
#  'Tot_Active_TL',
#  'Total_TL_opened_L6M',
#  'Tot_TL_closed_L6M',
#  'pct_tl_open_L6M',
#  'pct_tl_closed_L6M',
#  'pct_active_tl',
#  'pct_closed_tl',
#  'Total_TL_opened_L12M',
#  'Tot_TL_closed_L12M',
#  'pct_tl_open_L12M',
#  'pct_tl_closed_L12M',
#  'Tot_Missed_Pmnt',
#  'Auto_TL',
#  'CC_TL',
#  'Consumer_TL',
#  'Gold_TL',
#  'Home_TL',
#  'PL_TL',
#  'Secured_TL',
#  'Unsecured_TL',
#  'Other_TL',
#  'Age_Oldest_TL',
#  'Age_Newest_TL',
#  'time_since_recent_payment',
#  'num_times_delinquent',
#  'max_recent_level_of_deliq',
#  'num_deliq_6mts',
#  'num_deliq_12mts',
#  'num_deliq_6_12mts',
#  'num_times_30p_dpd',
#  'num_times_60p_dpd',
#  'num_std',
#  'num_std_6mts',
#  'num_std_12mts',
#  'num_sub',
#  'num_sub_6mts',
#  'num_sub_12mts',
#  'num_dbt',
#  'num_dbt_6mts',
#  'num_dbt_12mts',
#  'num_lss',
#  'num_lss_6mts',
#  'num_lss_12mts',
#  'recent_level_of_deliq',
#  'tot_enq',
#  'CC_enq',
#  'CC_enq_L6m',
#  'CC_enq_L12m',
#  'PL_enq',
#  'PL_enq_L6m',
#  'PL_enq_L12m',
#  'time_since_recent_enq',
#  'enq_L12m',
#  'enq_L6m',
#  'enq_L3m',
#  'AGE',
#  'NETMONTHLYINCOME',
#  'Time_With_Curr_Empr',
#  'pct_of_active_TLs_ever',
#  'pct_opened_TLs_L6m_of_L12m',
#  'pct_currentBal_all_TL',
#  'CC_Flag',
#  'PL_Flag',
#  'pct_PL_enq_L6m_of_L12m',
#  'pct_CC_enq_L6m_of_L12m',
#  'pct_PL_enq_L6m_of_ever',
#  'pct_CC_enq_L6m_of_ever',
#  'HL_Flag',
#  'GL_Flag',
#  'Credit_Score']

# %%
# VIF sequentially check
vif_data = df[numerical_log]
total_columns = vif_data.shape[1]
columns_to_be_kept = []
column_index = 0

# %%
for i in range (0,total_columns):
    
    vif_value = variance_inflation_factor(vif_data, column_index)
    print (column_index,'---',vif_value)
    
    # If VIF is less than 6, then keep the column
    if vif_value <= 6:
        columns_to_be_kept.append( numerical_log[i] )
        column_index = column_index + 1
    
    # If VIF is greater than 6, then drop the column
    else:
        vif_data = vif_data.drop([ numerical_log[i] ] , axis=1)
# Out:
# c:\Users\KIIT\anaconda3\envs\loan\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 0 --- inf
# c:\Users\KIIT\anaconda3\envs\loan\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 0 --- inf
# 0 --- 11.320180023967996
# 0 --- 8.363698035000336
# 0 --- 6.520647877790928
# 0 --- 5.149501618212625
# 1 --- 2.611111040579735
# c:\Users\KIIT\anaconda3\envs\loan\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 2 --- inf
# 2 --- 1788.7926256209232
# 2 --- 8.601028256477228
# 2 --- 3.8328007921530785
# 3 --- 6.099653381646739
# 3 --- 5.581352009642762
# 4 --- 1.985584353098778
# c:\Users\KIIT\anaconda3\envs\loan\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 5 --- inf
# 5 --- 4.809538302819343
# 6 --- 23.270628983464636
# 6 --- 30.595522588100053
# 6 --- 4.3843464059655854
# 7 --- 3.064658415523423
# 8 --- 2.898639771299253
# 9 --- 4.377876915347324
# 10 --- 2.207853583695844
# 11 --- 4.916914200506864
# 12 --- 5.214702030064725
# 13 --- 3.3861625024231476
# 14 --- 7.840583309478997
# 14 --- 5.255034641721438
# c:\Users\KIIT\anaconda3\envs\loan\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 15 --- inf
# 15 --- 7.380634506427232
# 15 --- 1.4210050015175733
# 16 --- 8.083255010190316
# 16 --- 1.6241227524040112
# 17 --- 7.257811920140003
# 17 --- 15.59624383268298
# 17 --- 1.825857047132431
# 18 --- 1.5080839450032664
# 19 --- 2.172088834824577
# 20 --- 2.62339755352723
# 21 --- 2.2959970812106176
# 22 --- 7.360578319196439
# 22 --- 2.1602387773102554
# 23 --- 2.8686288267891458
# 24 --- 6.458218003637277
# 24 --- 2.8474118865638265
# 25 --- 4.753198156284083
# 26 --- 16.22735475594825
# 26 --- 6.424377256363877
# 26 --- 8.887080381808687
# 26 --- 2.3804746142952653
# 27 --- 8.609513476514548
# 27 --- 13.06755093547673
# 27 --- 3.500040056654654
# 28 --- 1.9087955874813773
# 29 --- 17.006562234161628
# 29 --- 10.730485153719197
# 29 --- 2.3538497522950275
# 30 --- 22.104855915136433
# 30 --- 2.7971639638512906
# 31 --- 3.4241712032176985
# 32 --- 10.175021454450935
# 32 --- 6.408710354561301
# 32 --- 1.001151196262561
# 33 --- 3.069197305397274
# 34 --- 2.8091261600643715
# 35 --- 20.249538381980678
# 35 --- 15.864576541593774
# 35 --- 1.8331649740532172
# 36 --- 1.5680839909542037
# 37 --- 1.9307572353811682
# 38 --- 4.331265056645247
# 39 --- 9.390334396150173

# %%
# Before : 72 numerical features
# After  : 39 numerical features after VIF check

# %%
# check Anova for columns_to_be_kept 
from scipy.stats import f_oneway

columns_to_be_kept_numerical = []
for i in columns_to_be_kept:
    a = list(df[i])  
    b = list(df['Approved_Flag'])  
    
    group_P1 = [value for value, group in zip(a, b) if group == 'P1']
    group_P2 = [value for value, group in zip(a, b) if group == 'P2']
    group_P3 = [value for value, group in zip(a, b) if group == 'P3']
    group_P4 = [value for value, group in zip(a, b) if group == 'P4']

    f_statistic, p_value = f_oneway(group_P1, group_P2, group_P3, group_P4)

    if p_value <= 0.05:
        columns_to_be_kept_numerical.append(i)

# %%
len(columns_to_be_kept_numerical)
# Out:
# 37

# %%
# Feature Selection is done for cat and num features

# Listing all the final features
features = columns_to_be_kept_numerical + categorical_log
df = df[features + ['Approved_Flag']]
df.shape
# Out:
# (42064, 43)

# %%
print(categorical_log)
print(df['EDUCATION'].unique())
# Out:
# ['MARITALSTATUS', 'EDUCATION', 'GENDER', 'last_prod_enq2', 'first_prod_enq2']
# ['12TH' 'GRADUATE' 'SSC' 'POST-GRADUATE' 'UNDER GRADUATE' 'OTHERS'
#  'PROFESSIONAL']

# %%
# Ordinal feature - EDUCATION

# SSC           : 1
# 12TH          : 2
# GRADUATE      : 3
# UNDER GRADUATE: 3
# POST GRADUATE : 4
# OTHERS        : 1
# PROFESSIONAL  : 3

df.loc[df['EDUCATION'] == 'SSC', ['EDUCATION']]             = 1
df.loc[df['EDUCATION'] == '12TH', ['EDUCATION']]            = 2
df.loc[df['EDUCATION'] == 'GRADUATE', ['EDUCATION']]        = 3
df.loc[df['EDUCATION'] == 'UNDER GRADUATE', ['EDUCATION']]  = 3
df.loc[df['EDUCATION'] == 'POST-GRADUATE', ['EDUCATION']]   = 4
df.loc[df['EDUCATION'] == 'OTHERS', ['EDUCATION']]          = 1
df.loc[df['EDUCATION'] == 'PROFESSIONAL', ['EDUCATION']]    = 3

print(df['EDUCATION'].value_counts())
df['EDUCATION'] = df['EDUCATION'].astype('int')
# Out:
# EDUCATION
# 3    18931
# 2    11703
# 1     9532
# 4     1898
# Name: count, dtype: int64

# %%
df_encoded = pd.get_dummies(df, columns = ['MARITALSTATUS', 'GENDER', 'last_prod_enq2', 'first_prod_enq2'])
df_encoded.shape
# Out:
# (42064, 55)

# %%
k = df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42064 entries, 0 to 42063
# Data columns (total 55 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   pct_tl_open_L6M               42064 non-null  float64
#  1   pct_tl_closed_L6M             42064 non-null  float64
#  2   Tot_TL_closed_L12M            42064 non-null  int64
#  3   pct_tl_closed_L12M            42064 non-null  float64
#  4   Tot_Missed_Pmnt               42064 non-null  int64
#  5   CC_TL                         42064 non-null  int64
#  6   Home_TL                       42064 non-null  int64
#  7   PL_TL                         42064 non-null  int64
#  8   Secured_TL                    42064 non-null  int64
#  9   Unsecured_TL                  42064 non-null  int64
#  10  Other_TL                      42064 non-null  int64
#  11  Age_Oldest_TL                 42064 non-null  int64
#  12  Age_Newest_TL                 42064 non-null  int64
#  13  time_since_recent_payment     42064 non-null  int64
#  14  max_recent_level_of_deliq     42064 non-null  int64
#  15  num_deliq_6_12mts             42064 non-null  int64
#  16  num_times_60p_dpd             42064 non-null  int64
#  17  num_std_12mts                 42064 non-null  int64
#  18  num_sub                       42064 non-null  int64
#  19  num_sub_6mts                  42064 non-null  int64
#  20  num_sub_12mts                 42064 non-null  int64
#  21  num_dbt                       42064 non-null  int64
#  22  num_dbt_12mts                 42064 non-null  int64
#  23  num_lss                       42064 non-null  int64
#  24  recent_level_of_deliq         42064 non-null  int64
#  25  CC_enq_L12m                   42064 non-null  int64
#  26  PL_enq_L12m                   42064 non-null  int64
#  27  time_since_recent_enq         42064 non-null  int64
#  28  enq_L3m                       42064 non-null  int64
#  29  NETMONTHLYINCOME              42064 non-null  int64
#  30  Time_With_Curr_Empr           42064 non-null  int64
#  31  CC_Flag                       42064 non-null  int64
#  32  PL_Flag                       42064 non-null  int64
#  33  pct_PL_enq_L6m_of_ever        42064 non-null  float64
#  34  pct_CC_enq_L6m_of_ever        42064 non-null  float64
#  35  HL_Flag                       42064 non-null  int64
#  36  GL_Flag                       42064 non-null  int64
#  37  EDUCATION                     42064 non-null  int32
#  38  Approved_Flag                 42064 non-null  object
#  39  MARITALSTATUS_Married         42064 non-null  bool
#  40  MARITALSTATUS_Single          42064 non-null  bool
#  41  GENDER_F                      42064 non-null  bool
#  42  GENDER_M                      42064 non-null  bool
#  43  last_prod_enq2_AL             42064 non-null  bool
#  44  last_prod_enq2_CC             42064 non-null  bool
#  45  last_prod_enq2_ConsumerLoan   42064 non-null  bool
#  46  last_prod_enq2_HL             42064 non-null  bool
#  47  last_prod_enq2_PL             42064 non-null  bool
#  48  last_prod_enq2_others         42064 non-null  bool
#  49  first_prod_enq2_AL            42064 non-null  bool
#  50  first_prod_enq2_CC            42064 non-null  bool
#  51  first_prod_enq2_ConsumerLoan  42064 non-null  bool
#  52  first_prod_enq2_HL            42064 non-null  bool
#  53  first_prod_enq2_PL            42064 non-null  bool
#  54  first_prod_enq2_others        42064 non-null  bool
# dtypes: bool(16), float64(5), int32(1), int64(32), object(1)
# memory usage: 13.0+ MB

# %%
df['Approved_Flag'].value_counts()
# Out:
# Approved_Flag
# P2    25452
# P3     6440
# P4     5264
# P1     4908
# Name: count, dtype: int64

# %%
# Data Preprocessing

# 1. Random Forest Classifier

X = df_encoded.drop(['Approved_Flag'], axis = 1)
Y = df_encoded['Approved_Flag']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

rf = RandomForestClassifier(n_estimators = 200, random_state = 42)
rf.fit(X_train, Y_train)

Y_pred = rf.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
print(f'Accuracy : {accuracy}')
precision, recall, f1_score, _ = precision_recall_fscore_support(Y_test, Y_pred)
for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f'class {v} : precision : {precision[i]}, recall : {recall[i]}, f1_score : {f1_score[i]}')
# Out:
# Accuracy : 0.7636990372043266
# class p1 : precision : 0.8370457209847597, recall : 0.7041420118343196, f1_score : 0.7648634172469202
# class p2 : precision : 0.7957519116397621, recall : 0.9282457879088206, f1_score : 0.856907593778591
# class p3 : precision : 0.4423380726698262, recall : 0.21132075471698114, f1_score : 0.28600612870275793
# class p4 : precision : 0.7178502879078695, recall : 0.7269193391642371, f1_score : 0.7223563495895703

# %%
# !pip install xgboost

# %%
# 2. xgboost

from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder

X = df_encoded.drop(['Approved_Flag'], axis = 1)
Y = df_encoded['Approved_Flag']

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, y_encoded, test_size = 0.2, random_state = 42)

xg = XGBClassifier(objective = 'multi:softmax', num_class = 4, random_state = 42)
xg.fit(X_train, Y_train)

Y_pred = xg.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
print(f'Accuracy : {accuracy}')

precision, recall, f1_score, _ = precision_recall_fscore_support(Y_test, Y_pred)
for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f'class {v} : precision : {precision[i]}, recall : {recall[i]}, f1_score : {f1_score[i]}')
# Out:
# Accuracy : 0.7783192677998336
# class p1 : precision : 0.823906083244397, recall : 0.7613412228796844, f1_score : 0.7913890312660175
# class p2 : precision : 0.8255418233924413, recall : 0.913577799801784, f1_score : 0.8673315769665035
# class p3 : precision : 0.4756380510440835, recall : 0.30943396226415093, f1_score : 0.37494284407864653
# class p4 : precision : 0.7342386032977691, recall : 0.7356656948493683, f1_score : 0.7349514563106796

# %%
# 3. Decision Tree

from sklearn.tree import DecisionTreeClassifier

X = df_encoded.drop(['Approved_Flag'], axis = 1)
Y = df_encoded['Approved_Flag']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

dt = DecisionTreeClassifier(random_state = 42)
dt.fit(X_train, Y_train)

Y_pred = dt.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
print(f'Accuracy : {accuracy}')
precision, recall, f1_score, _ = precision_recall_fscore_support(Y_test, Y_pred)
for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f'class {v} : precision : {precision[i]}, recall : {recall[i]}, f1_score : {f1_score[i]}')
# Out:
# Accuracy : 0.7021276595744681
# class p1 : precision : 0.7207661290322581, recall : 0.7051282051282052, f1_score : 0.7128614157527418
# class p2 : precision : 0.8134373125374925, recall : 0.8063429137760159, f1_score : 0.8098745769460481
# class p3 : precision : 0.3391430646332607, recall : 0.35245283018867923, f1_score : 0.3456698741672835
# class p4 : precision : 0.6299137104506232, recall : 0.6384839650145773, f1_score : 0.6341698841698842

# %%
# XGBoost is the best model

# Define the hyperparameter grid

param_grid = {
    'colsample_bytree': [0.1, 0.3, 0.5, 0.7, 0.9],
    'learning_rate': [0.1, 0.01, 0.001],
    'max_depth': [3, 5, 7, 9],
    'n_estimators': [100, 200, 300, 400, 500],
    'alpha': [10, 20, 30, 40, 50]
}

index = 0

answers_grid = {
    'combination'       : [],
    'train_accuracy'    : [],
    'test_accuracy'     : [],
    'colsample_bytree'  : [],
    'learning_rate'     : [],
    'max_depth'         : [],
    'n_estimators'      : [],
    'alpha'             : []
}

# %%
# Loop through each combination of hyperparameters

for colsample_bytree in param_grid['colsample_bytree']:
    for learning_rate in param_grid['learning_rate']:
        for max_depth in param_grid['max_depth']:
            for n_estimators in param_grid['n_estimators']:
                for alpha in param_grid['alpha']:
                    
                    index = index + 1
                    
                    # Define and train the model
                    model = XGBClassifier(
                        colsample_bytree = colsample_bytree,
                        learning_rate = learning_rate,
                        max_depth = max_depth,
                        n_estimators = n_estimators,
                        alpha = alpha,
                        objective = 'multi:softmax',
                        num_class = 4,
                        random_state = 42
                    )
                    
                    y = df_encoded['Approved_Flag']
                    y_encoded = label_encoder.fit_transform(y)
                    
                    X_train, X_test, Y_train, Y_test = train_test_split(X, y_encoded, test_size = 0.2, random_state = 42)
                    
                    model.fit(X_train, Y_train)
                    
                    # Predict on the training and test data
                    Y_train_pred = model.predict(X_train)
                    Y_test_pred = model.predict(X_test)
                    
                    # Calculate the accuracy
                    train_accuracy = accuracy_score(Y_train, Y_train_pred)
                    test_accuracy = accuracy_score(Y_test, Y_test_pred)
                    
                    # Save the results
                    answers_grid['combination'].append(index)
                    answers_grid['train_accuracy'].append(train_accuracy)
                    answers_grid['test_accuracy'].append(test_accuracy)
                    answers_grid['colsample_bytree'].append(colsample_bytree)
                    answers_grid['learning_rate'].append(learning_rate)
                    answers_grid['max_depth'].append(max_depth)
                    answers_grid['n_estimators'].append(n_estimators)
                    answers_grid['alpha'].append(alpha)
                    
                    # Print the results
                    print(f'Combination : {index}')
                    print(f'colsample_bytree : {colsample_bytree}, learning_rate : {learning_rate}, max_depth : {max_depth}, n_estimators : {n_estimators}, alpha : {alpha}')
                    print(f'Train Accuracy : {train_accuracy:.2f}')
                    print(f'Test Accuracy : {test_accuracy:.2f}')
# Out:
# Combination : 1
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 100, alpha : 10
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 2
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 100, alpha : 20
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 3
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 100, alpha : 30
# Train Accuracy : 0.71
# Test Accuracy : 0.71
# Combination : 4
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 100, alpha : 40
# Train Accuracy : 0.71
# Test Accuracy : 0.70
# Combination : 5
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 100, alpha : 50
# Train Accuracy : 0.71
# Test Accuracy : 0.70
# Combination : 6
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 200, alpha : 10
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 7
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 200, alpha : 20
# Train Accuracy : 0.75
# Test Accuracy : 0.75
# Combination : 8
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 200, alpha : 30
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 9
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 200, alpha : 40
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 10
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 200, alpha : 50
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 11
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 300, alpha : 10
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 12
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 300, alpha : 20
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 13
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 300, alpha : 30
# Train Accuracy : 0.76
# Test Accuracy : 0.76
# Combination : 14
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 300, alpha : 40
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 15
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 300, alpha : 50
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 16
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 400, alpha : 10
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 17
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 400, alpha : 20
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 18
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 400, alpha : 30
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 19
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 400, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 20
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 400, alpha : 50
# Train Accuracy : 0.76
# Test Accuracy : 0.76
# Combination : 21
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 500, alpha : 10
# Train Accuracy : 0.78
# Test Accuracy : 0.77
# Combination : 22
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 500, alpha : 20
# Train Accuracy : 0.78
# Test Accuracy : 0.77
# Combination : 23
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 500, alpha : 30
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 24
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 500, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 25
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 3, n_estimators : 500, alpha : 50
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 26
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 100, alpha : 10
# Train Accuracy : 0.73
# Test Accuracy : 0.72
# Combination : 27
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 100, alpha : 20
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 28
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 100, alpha : 30
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 29
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 100, alpha : 40
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 30
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 100, alpha : 50
# Train Accuracy : 0.71
# Test Accuracy : 0.71
# Combination : 31
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 200, alpha : 10
# Train Accuracy : 0.77
# Test Accuracy : 0.75
# Combination : 32
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 200, alpha : 20
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 33
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 200, alpha : 30
# Train Accuracy : 0.76
# Test Accuracy : 0.74
# Combination : 34
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 200, alpha : 40
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 35
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 200, alpha : 50
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 36
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 300, alpha : 10
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 37
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 300, alpha : 20
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 38
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 300, alpha : 30
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 39
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 300, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 40
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 300, alpha : 50
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 41
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 400, alpha : 10
# Train Accuracy : 0.79
# Test Accuracy : 0.77
# Combination : 42
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 400, alpha : 20
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 43
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 400, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 44
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 400, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 45
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 400, alpha : 50
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 46
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 500, alpha : 10
# Train Accuracy : 0.80
# Test Accuracy : 0.77
# Combination : 47
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 500, alpha : 20
# Train Accuracy : 0.79
# Test Accuracy : 0.77
# Combination : 48
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 500, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.77
# Combination : 49
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 500, alpha : 40
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 50
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 5, n_estimators : 500, alpha : 50
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 51
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 100, alpha : 10
# Train Accuracy : 0.73
# Test Accuracy : 0.72
# Combination : 52
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 100, alpha : 20
# Train Accuracy : 0.73
# Test Accuracy : 0.71
# Combination : 53
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 100, alpha : 30
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 54
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 100, alpha : 40
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 55
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 100, alpha : 50
# Train Accuracy : 0.71
# Test Accuracy : 0.71
# Combination : 56
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 200, alpha : 10
# Train Accuracy : 0.77
# Test Accuracy : 0.75
# Combination : 57
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 200, alpha : 20
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 58
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 200, alpha : 30
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 59
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 200, alpha : 40
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 60
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 200, alpha : 50
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 61
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 300, alpha : 10
# Train Accuracy : 0.79
# Test Accuracy : 0.76
# Combination : 62
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 300, alpha : 20
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 63
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 300, alpha : 30
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 64
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 300, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 65
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 300, alpha : 50
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 66
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 400, alpha : 10
# Train Accuracy : 0.80
# Test Accuracy : 0.77
# Combination : 67
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 400, alpha : 20
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 68
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 400, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 69
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 400, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 70
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 400, alpha : 50
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 71
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 500, alpha : 10
# Train Accuracy : 0.80
# Test Accuracy : 0.77
# Combination : 72
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 500, alpha : 20
# Train Accuracy : 0.79
# Test Accuracy : 0.77
# Combination : 73
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 500, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 74
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 500, alpha : 40
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 75
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 7, n_estimators : 500, alpha : 50
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 76
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 100, alpha : 10
# Train Accuracy : 0.73
# Test Accuracy : 0.72
# Combination : 77
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 100, alpha : 20
# Train Accuracy : 0.73
# Test Accuracy : 0.71
# Combination : 78
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 100, alpha : 30
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 79
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 100, alpha : 40
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 80
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 100, alpha : 50
# Train Accuracy : 0.71
# Test Accuracy : 0.71
# Combination : 81
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 200, alpha : 10
# Train Accuracy : 0.77
# Test Accuracy : 0.75
# Combination : 82
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 200, alpha : 20
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 83
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 200, alpha : 30
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 84
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 200, alpha : 40
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 85
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 200, alpha : 50
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 86
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 300, alpha : 10
# Train Accuracy : 0.79
# Test Accuracy : 0.76
# Combination : 87
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 300, alpha : 20
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 88
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 300, alpha : 30
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 89
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 300, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 90
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 300, alpha : 50
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 91
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 400, alpha : 10
# Train Accuracy : 0.80
# Test Accuracy : 0.77
# Combination : 92
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 400, alpha : 20
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 93
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 400, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 94
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 400, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 95
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 400, alpha : 50
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 96
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 500, alpha : 10
# Train Accuracy : 0.81
# Test Accuracy : 0.77
# Combination : 97
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 500, alpha : 20
# Train Accuracy : 0.79
# Test Accuracy : 0.77
# Combination : 98
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 500, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.77
# Combination : 99
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 500, alpha : 40
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 100
# colsample_bytree : 0.1, learning_rate : 0.1, max_depth : 9, n_estimators : 500, alpha : 50
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 101
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 100, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 102
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 100, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 103
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 100, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 104
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 100, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 105
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 100, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 106
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 200, alpha : 10
# Train Accuracy : 0.62
# Test Accuracy : 0.62
# Combination : 107
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 200, alpha : 20
# Train Accuracy : 0.62
# Test Accuracy : 0.61
# Combination : 108
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 200, alpha : 30
# Train Accuracy : 0.62
# Test Accuracy : 0.61
# Combination : 109
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 200, alpha : 40
# Train Accuracy : 0.62
# Test Accuracy : 0.61
# Combination : 110
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 200, alpha : 50
# Train Accuracy : 0.62
# Test Accuracy : 0.61
# Combination : 111
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 300, alpha : 10
# Train Accuracy : 0.64
# Test Accuracy : 0.64
# Combination : 112
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 300, alpha : 20
# Train Accuracy : 0.64
# Test Accuracy : 0.64
# Combination : 113
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 300, alpha : 30
# Train Accuracy : 0.64
# Test Accuracy : 0.63
# Combination : 114
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 300, alpha : 40
# Train Accuracy : 0.64
# Test Accuracy : 0.63
# Combination : 115
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 300, alpha : 50
# Train Accuracy : 0.64
# Test Accuracy : 0.63
# Combination : 116
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 400, alpha : 10
# Train Accuracy : 0.66
# Test Accuracy : 0.65
# Combination : 117
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 400, alpha : 20
# Train Accuracy : 0.66
# Test Accuracy : 0.65
# Combination : 118
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 400, alpha : 30
# Train Accuracy : 0.66
# Test Accuracy : 0.65
# Combination : 119
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 400, alpha : 40
# Train Accuracy : 0.66
# Test Accuracy : 0.65
# Combination : 120
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 400, alpha : 50
# Train Accuracy : 0.65
# Test Accuracy : 0.65
# Combination : 121
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 500, alpha : 10
# Train Accuracy : 0.67
# Test Accuracy : 0.67
# Combination : 122
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 500, alpha : 20
# Train Accuracy : 0.67
# Test Accuracy : 0.67
# Combination : 123
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 500, alpha : 30
# Train Accuracy : 0.67
# Test Accuracy : 0.66
# Combination : 124
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 500, alpha : 40
# Train Accuracy : 0.67
# Test Accuracy : 0.66
# Combination : 125
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 3, n_estimators : 500, alpha : 50
# Train Accuracy : 0.67
# Test Accuracy : 0.66
# Combination : 126
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 100, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 127
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 100, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 128
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 100, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 129
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 100, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 130
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 100, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 131
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 200, alpha : 10
# Train Accuracy : 0.63
# Test Accuracy : 0.62
# Combination : 132
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 200, alpha : 20
# Train Accuracy : 0.62
# Test Accuracy : 0.62
# Combination : 133
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 200, alpha : 30
# Train Accuracy : 0.62
# Test Accuracy : 0.62
# Combination : 134
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 200, alpha : 40
# Train Accuracy : 0.62
# Test Accuracy : 0.61
# Combination : 135
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 200, alpha : 50
# Train Accuracy : 0.62
# Test Accuracy : 0.61
# Combination : 136
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 300, alpha : 10
# Train Accuracy : 0.65
# Test Accuracy : 0.64
# Combination : 137
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 300, alpha : 20
# Train Accuracy : 0.65
# Test Accuracy : 0.64
# Combination : 138
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 300, alpha : 30
# Train Accuracy : 0.64
# Test Accuracy : 0.64
# Combination : 139
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 300, alpha : 40
# Train Accuracy : 0.64
# Test Accuracy : 0.64
# Combination : 140
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 300, alpha : 50
# Train Accuracy : 0.64
# Test Accuracy : 0.63
# Combination : 141
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 400, alpha : 10
# Train Accuracy : 0.67
# Test Accuracy : 0.66
# Combination : 142
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 400, alpha : 20
# Train Accuracy : 0.66
# Test Accuracy : 0.66
# Combination : 143
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 400, alpha : 30
# Train Accuracy : 0.66
# Test Accuracy : 0.66
# Combination : 144
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 400, alpha : 40
# Train Accuracy : 0.66
# Test Accuracy : 0.65
# Combination : 145
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 400, alpha : 50
# Train Accuracy : 0.66
# Test Accuracy : 0.65
# Combination : 146
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 500, alpha : 10
# Train Accuracy : 0.68
# Test Accuracy : 0.68
# Combination : 147
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 500, alpha : 20
# Train Accuracy : 0.68
# Test Accuracy : 0.67
# Combination : 148
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 500, alpha : 30
# Train Accuracy : 0.67
# Test Accuracy : 0.67
# Combination : 149
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 500, alpha : 40
# Train Accuracy : 0.67
# Test Accuracy : 0.66
# Combination : 150
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 5, n_estimators : 500, alpha : 50
# Train Accuracy : 0.67
# Test Accuracy : 0.66
# Combination : 151
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 100, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 152
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 100, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 153
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 100, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 154
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 100, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 155
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 100, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 156
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 200, alpha : 10
# Train Accuracy : 0.63
# Test Accuracy : 0.62
# Combination : 157
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 200, alpha : 20
# Train Accuracy : 0.63
# Test Accuracy : 0.62
# Combination : 158
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 200, alpha : 30
# Train Accuracy : 0.62
# Test Accuracy : 0.62
# Combination : 159
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 200, alpha : 40
# Train Accuracy : 0.62
# Test Accuracy : 0.61
# Combination : 160
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 200, alpha : 50
# Train Accuracy : 0.62
# Test Accuracy : 0.61
# Combination : 161
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 300, alpha : 10
# Train Accuracy : 0.65
# Test Accuracy : 0.64
# Combination : 162
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 300, alpha : 20
# Train Accuracy : 0.65
# Test Accuracy : 0.64
# Combination : 163
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 300, alpha : 30
# Train Accuracy : 0.64
# Test Accuracy : 0.64
# Combination : 164
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 300, alpha : 40
# Train Accuracy : 0.64
# Test Accuracy : 0.64
# Combination : 165
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 300, alpha : 50
# Train Accuracy : 0.64
# Test Accuracy : 0.63
# Combination : 166
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 400, alpha : 10
# Train Accuracy : 0.67
# Test Accuracy : 0.66
# Combination : 167
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 400, alpha : 20
# Train Accuracy : 0.66
# Test Accuracy : 0.66
# Combination : 168
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 400, alpha : 30
# Train Accuracy : 0.66
# Test Accuracy : 0.66
# Combination : 169
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 400, alpha : 40
# Train Accuracy : 0.66
# Test Accuracy : 0.65
# Combination : 170
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 400, alpha : 50
# Train Accuracy : 0.66
# Test Accuracy : 0.65
# Combination : 171
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 500, alpha : 10
# Train Accuracy : 0.69
# Test Accuracy : 0.68
# Combination : 172
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 500, alpha : 20
# Train Accuracy : 0.68
# Test Accuracy : 0.67
# Combination : 173
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 500, alpha : 30
# Train Accuracy : 0.68
# Test Accuracy : 0.67
# Combination : 174
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 500, alpha : 40
# Train Accuracy : 0.67
# Test Accuracy : 0.67
# Combination : 175
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 7, n_estimators : 500, alpha : 50
# Train Accuracy : 0.67
# Test Accuracy : 0.66
# Combination : 176
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 100, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 177
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 100, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 178
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 100, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 179
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 100, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 180
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 100, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 181
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 200, alpha : 10
# Train Accuracy : 0.63
# Test Accuracy : 0.62
# Combination : 182
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 200, alpha : 20
# Train Accuracy : 0.63
# Test Accuracy : 0.62
# Combination : 183
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 200, alpha : 30
# Train Accuracy : 0.62
# Test Accuracy : 0.62
# Combination : 184
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 200, alpha : 40
# Train Accuracy : 0.62
# Test Accuracy : 0.61
# Combination : 185
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 200, alpha : 50
# Train Accuracy : 0.62
# Test Accuracy : 0.61
# Combination : 186
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 300, alpha : 10
# Train Accuracy : 0.65
# Test Accuracy : 0.64
# Combination : 187
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 300, alpha : 20
# Train Accuracy : 0.65
# Test Accuracy : 0.64
# Combination : 188
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 300, alpha : 30
# Train Accuracy : 0.64
# Test Accuracy : 0.64
# Combination : 189
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 300, alpha : 40
# Train Accuracy : 0.64
# Test Accuracy : 0.64
# Combination : 190
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 300, alpha : 50
# Train Accuracy : 0.64
# Test Accuracy : 0.63
# Combination : 191
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 400, alpha : 10
# Train Accuracy : 0.67
# Test Accuracy : 0.66
# Combination : 192
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 400, alpha : 20
# Train Accuracy : 0.66
# Test Accuracy : 0.66
# Combination : 193
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 400, alpha : 30
# Train Accuracy : 0.66
# Test Accuracy : 0.66
# Combination : 194
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 400, alpha : 40
# Train Accuracy : 0.66
# Test Accuracy : 0.65
# Combination : 195
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 400, alpha : 50
# Train Accuracy : 0.66
# Test Accuracy : 0.65
# Combination : 196
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 500, alpha : 10
# Train Accuracy : 0.69
# Test Accuracy : 0.68
# Combination : 197
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 500, alpha : 20
# Train Accuracy : 0.68
# Test Accuracy : 0.67
# Combination : 198
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 500, alpha : 30
# Train Accuracy : 0.67
# Test Accuracy : 0.67
# Combination : 199
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 500, alpha : 40
# Train Accuracy : 0.67
# Test Accuracy : 0.67
# Combination : 200
# colsample_bytree : 0.1, learning_rate : 0.01, max_depth : 9, n_estimators : 500, alpha : 50
# Train Accuracy : 0.67
# Test Accuracy : 0.66
# Combination : 201
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 100, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 202
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 100, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 203
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 100, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 204
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 100, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 205
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 100, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 206
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 200, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 207
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 200, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 208
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 200, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 209
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 200, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 210
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 200, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 211
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 300, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 212
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 300, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 213
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 300, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 214
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 300, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 215
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 300, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 216
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 400, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 217
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 400, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 218
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 400, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 219
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 400, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 220
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 400, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 221
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 500, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 222
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 500, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 223
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 500, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 224
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 500, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 225
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 3, n_estimators : 500, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 226
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 100, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 227
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 100, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 228
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 100, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 229
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 100, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 230
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 100, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 231
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 200, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 232
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 200, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 233
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 200, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 234
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 200, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 235
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 200, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 236
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 300, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 237
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 300, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 238
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 300, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 239
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 300, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 240
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 300, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 241
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 400, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 242
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 400, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 243
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 400, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 244
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 400, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 245
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 400, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 246
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 500, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 247
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 500, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 248
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 500, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 249
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 500, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 250
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 5, n_estimators : 500, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 251
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 100, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 252
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 100, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 253
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 100, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 254
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 100, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 255
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 100, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 256
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 200, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 257
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 200, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 258
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 200, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 259
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 200, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 260
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 200, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 261
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 300, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 262
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 300, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 263
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 300, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 264
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 300, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 265
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 300, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 266
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 400, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 267
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 400, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 268
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 400, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 269
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 400, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 270
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 400, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 271
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 500, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 272
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 500, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 273
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 500, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 274
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 500, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 275
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 7, n_estimators : 500, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 276
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 100, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 277
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 100, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 278
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 100, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 279
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 100, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 280
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 100, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 281
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 200, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 282
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 200, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 283
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 200, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 284
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 200, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 285
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 200, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 286
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 300, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 287
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 300, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 288
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 300, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 289
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 300, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 290
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 300, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 291
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 400, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 292
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 400, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 293
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 400, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 294
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 400, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 295
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 400, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 296
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 500, alpha : 10
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 297
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 500, alpha : 20
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 298
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 500, alpha : 30
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 299
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 500, alpha : 40
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 300
# colsample_bytree : 0.1, learning_rate : 0.001, max_depth : 9, n_estimators : 500, alpha : 50
# Train Accuracy : 0.61
# Test Accuracy : 0.60
# Combination : 301
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 100, alpha : 10
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 302
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 100, alpha : 20
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 303
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 100, alpha : 30
# Train Accuracy : 0.76
# Test Accuracy : 0.76
# Combination : 304
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 100, alpha : 40
# Train Accuracy : 0.76
# Test Accuracy : 0.76
# Combination : 305
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 100, alpha : 50
# Train Accuracy : 0.76
# Test Accuracy : 0.76
# Combination : 306
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 200, alpha : 10
# Train Accuracy : 0.78
# Test Accuracy : 0.77
# Combination : 307
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 200, alpha : 20
# Train Accuracy : 0.78
# Test Accuracy : 0.77
# Combination : 308
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 200, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.77
# Combination : 309
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 200, alpha : 40
# Train Accuracy : 0.78
# Test Accuracy : 0.77
# Combination : 310
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 200, alpha : 50
# Train Accuracy : 0.78
# Test Accuracy : 0.77
# Combination : 311
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 300, alpha : 10
# Train Accuracy : 0.79
# Test Accuracy : 0.78
# Combination : 312
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 300, alpha : 20
# Train Accuracy : 0.79
# Test Accuracy : 0.78
# Combination : 313
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 300, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.77
# Combination : 314
# colsample_bytree : 0.3, learning_rate : 0.1, max_depth : 3, n_estimators : 300, alpha : 40
# Train Accuracy : 0.78
# Test Accuracy : 0.77
# Combination : 315
# ...
# Test Accuracy : 0.78
# Combination : 1398
# colsample_bytree : 0.9, learning_rate : 0.01, max_depth : 9, n_estimators : 500, alpha : 30
# Train Accuracy : 0.79
# Test Accuracy : 0.77
# Combination : 1399
# colsample_bytree : 0.9, learning_rate : 0.01, max_depth : 9, n_estimators : 500, alpha : 40
# Train Accuracy : 0.79
# Test Accuracy : 0.78
# Combination : 1400
# colsample_bytree : 0.9, learning_rate : 0.01, max_depth : 9, n_estimators : 500, alpha : 50
# Train Accuracy : 0.79
# Test Accuracy : 0.77
# Combination : 1401
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 100, alpha : 10
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1402
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 100, alpha : 20
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1403
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 100, alpha : 30
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1404
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 100, alpha : 40
# Train Accuracy : 0.71
# Test Accuracy : 0.70
# Combination : 1405
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 100, alpha : 50
# Train Accuracy : 0.71
# Test Accuracy : 0.70
# Combination : 1406
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 200, alpha : 10
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1407
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 200, alpha : 20
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1408
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 200, alpha : 30
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1409
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 200, alpha : 40
# Train Accuracy : 0.71
# Test Accuracy : 0.71
# Combination : 1410
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 200, alpha : 50
# Train Accuracy : 0.71
# Test Accuracy : 0.71
# Combination : 1411
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 300, alpha : 10
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1412
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 300, alpha : 20
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1413
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 300, alpha : 30
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1414
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 300, alpha : 40
# Train Accuracy : 0.71
# Test Accuracy : 0.71
# Combination : 1415
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 300, alpha : 50
# Train Accuracy : 0.71
# Test Accuracy : 0.71
# Combination : 1416
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 400, alpha : 10
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1417
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 400, alpha : 20
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1418
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 400, alpha : 30
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1419
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 400, alpha : 40
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1420
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 400, alpha : 50
# Train Accuracy : 0.71
# Test Accuracy : 0.71
# Combination : 1421
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 500, alpha : 10
# Train Accuracy : 0.72
# Test Accuracy : 0.72
# Combination : 1422
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 500, alpha : 20
# Train Accuracy : 0.72
# Test Accuracy : 0.72
# Combination : 1423
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 500, alpha : 30
# Train Accuracy : 0.72
# Test Accuracy : 0.71
# Combination : 1424
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 500, alpha : 40
# Train Accuracy : 0.72
# Test Accuracy : 0.72
# Combination : 1425
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 3, n_estimators : 500, alpha : 50
# Train Accuracy : 0.71
# Test Accuracy : 0.71
# Combination : 1426
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 100, alpha : 10
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1427
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 100, alpha : 20
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1428
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 100, alpha : 30
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1429
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 100, alpha : 40
# Train Accuracy : 0.74
# Test Accuracy : 0.74
# Combination : 1430
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 100, alpha : 50
# Train Accuracy : 0.74
# Test Accuracy : 0.74
# Combination : 1431
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 200, alpha : 10
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1432
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 200, alpha : 20
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1433
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 200, alpha : 30
# Train Accuracy : 0.74
# Test Accuracy : 0.74
# Combination : 1434
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 200, alpha : 40
# Train Accuracy : 0.74
# Test Accuracy : 0.73
# Combination : 1435
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 200, alpha : 50
# Train Accuracy : 0.74
# Test Accuracy : 0.73
# Combination : 1436
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 300, alpha : 10
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1437
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 300, alpha : 20
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1438
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 300, alpha : 30
# Train Accuracy : 0.74
# Test Accuracy : 0.74
# Combination : 1439
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 300, alpha : 40
# Train Accuracy : 0.74
# Test Accuracy : 0.73
# Combination : 1440
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 300, alpha : 50
# Train Accuracy : 0.74
# Test Accuracy : 0.73
# Combination : 1441
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 400, alpha : 10
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1442
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 400, alpha : 20
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1443
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 400, alpha : 30
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1444
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 400, alpha : 40
# Train Accuracy : 0.74
# Test Accuracy : 0.74
# Combination : 1445
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 400, alpha : 50
# Train Accuracy : 0.74
# Test Accuracy : 0.73
# Combination : 1446
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 500, alpha : 10
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1447
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 500, alpha : 20
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1448
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 500, alpha : 30
# Train Accuracy : 0.75
# Test Accuracy : 0.74
# Combination : 1449
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 500, alpha : 40
# Train Accuracy : 0.74
# Test Accuracy : 0.74
# Combination : 1450
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 5, n_estimators : 500, alpha : 50
# Train Accuracy : 0.74
# Test Accuracy : 0.74
# Combination : 1451
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 100, alpha : 10
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1452
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 100, alpha : 20
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1453
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 100, alpha : 30
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1454
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 100, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.75
# Combination : 1455
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 100, alpha : 50
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 1456
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 200, alpha : 10
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1457
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 200, alpha : 20
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1458
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 200, alpha : 30
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1459
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 200, alpha : 40
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 1460
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 200, alpha : 50
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 1461
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 300, alpha : 10
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1462
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 300, alpha : 20
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1463
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 300, alpha : 30
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1464
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 300, alpha : 40
# Train Accuracy : 0.76
# Test Accuracy : 0.76
# Combination : 1465
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 300, alpha : 50
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 1466
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 400, alpha : 10
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1467
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 400, alpha : 20
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1468
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 400, alpha : 30
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1469
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 400, alpha : 40
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 1470
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 400, alpha : 50
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 1471
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 500, alpha : 10
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1472
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 500, alpha : 20
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1473
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 500, alpha : 30
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1474
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 500, alpha : 40
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 1475
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 7, n_estimators : 500, alpha : 50
# Train Accuracy : 0.76
# Test Accuracy : 0.75
# Combination : 1476
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 100, alpha : 10
# Train Accuracy : 0.79
# Test Accuracy : 0.76
# Combination : 1477
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 100, alpha : 20
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1478
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 100, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1479
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 100, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1480
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 100, alpha : 50
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1481
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 200, alpha : 10
# Train Accuracy : 0.79
# Test Accuracy : 0.76
# Combination : 1482
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 200, alpha : 20
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1483
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 200, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1484
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 200, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1485
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 200, alpha : 50
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1486
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 300, alpha : 10
# Train Accuracy : 0.79
# Test Accuracy : 0.77
# Combination : 1487
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 300, alpha : 20
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1488
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 300, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1489
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 300, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1490
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 300, alpha : 50
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1491
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 400, alpha : 10
# Train Accuracy : 0.79
# Test Accuracy : 0.77
# Combination : 1492
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 400, alpha : 20
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1493
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 400, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1494
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 400, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1495
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 400, alpha : 50
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1496
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 500, alpha : 10
# Train Accuracy : 0.79
# Test Accuracy : 0.77
# Combination : 1497
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 500, alpha : 20
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1498
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 500, alpha : 30
# Train Accuracy : 0.78
# Test Accuracy : 0.76
# Combination : 1499
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 500, alpha : 40
# Train Accuracy : 0.77
# Test Accuracy : 0.76
# Combination : 1500
# colsample_bytree : 0.9, learning_rate : 0.001, max_depth : 9, n_estimators : 500, alpha : 50
# Train Accuracy : 0.77
# Test Accuracy : 0.76

# %%
parameter = pd.DataFrame(answers_grid)
parameter.to_csv('./model/parameter.csv', index = False)

# %%
model = XGBClassifier(
    colsample_bytree = 0.7,
    learning_rate = 0.1,
    max_depth = 3,
    n_estimators = 300,
    alpha = 40,
)

model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
print(f'Accuracy : {accuracy}')
# Out:
# Accuracy : 0.7782004041364555

# %%
import pickle

filename = './model/loan_v1.sav'
with open(filename, 'wb') as f:
    pickle.dump(model, f)

# %%
filename = './model/loan_v1.sav'

with open(filename, 'rb') as f:
    load_model = pickle.load(f)

Y_pred = load_model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)

# %%
print(f'Accuracy : {accuracy}')
# Out:
# Accuracy : 0.7782004041364555
